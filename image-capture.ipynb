# %%
# Import opencv
import cv2 

# Import uuid
import uuid

# Import Operating System
import os

# Import time
import time

WIDTH = 1280
HEIGHT = 720

# %%
labels = ['Acid', 'Alkali']

# %%
IMAGES_PATH = os.path.join('Indicator-Network','workspace','images','collected_images_2')

# %%
label = 'Acid'
cap = cv2.VideoCapture(0)
cap.set(cv2.CAP_PROP_FRAME_WIDTH, WIDTH)
cap.set(cv2.CAP_PROP_FRAME_HEIGHT, HEIGHT)
print('Collecting images for {}'.format(label))
time.sleep(5)
while True:
    print('Collecting image.')
    ret, frame = cap.read()
    imgname = os.path.join(IMAGES_PATH,label,label+'.'+'{}.jpg'.format(str(uuid.uuid1())))
    cv2.imwrite(imgname, frame)
    cv2.imshow('frame', frame)
    time.sleep(2)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# Collecting images for Acid
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
# Collecting image.
